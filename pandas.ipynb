# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\Dr Maha Abdallah\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
! pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\Dr Maha Abdallah\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# learn pandas

# %%
pip install pandas  --default-timeout=100
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\Dr Maha Abdallah\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
pd.Series(10)
# Out:
# 0    10
# dtype: int64

# %%
numbers = [10,11,12,13]
pd.Series(numbers)
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# dtype: int64

# %%
data = pd.Series([10,11,12,13])
type(data.values)
# Out:
# numpy.ndarray

# %%
data = pd.Series([10,11,12,13], index = ['frist','second','third','fourth'])
print(data)
data["second"]
# Out:
# frist     10
# second    11
# third     12
# fourth    13
# dtype: int64
# np.int64(11)

# %%
Dictionary = {
    "ahmed":1234,
    "maha":2345,
    "Naglaa":5678,
    "noha":9876
}
student = pd.Series(Dictionary)
print(student)
# Out:
# ahmed     1234
# maha      2345
# Naglaa    5678
# noha      9876
# dtype: int64

# %%
Dictionary = {
    "ahmed":12,
    "maha":34,
    "Naglaa":56,
    "noha":78
}
id = pd.Series(Dictionary)
print(id)
# Out:
# ahmed     12
# maha      34
# Naglaa    56
# noha      78
# dtype: int64

# %%
pd.DataFrame(
    {"population" : [12,34,56,78]}
)
# Out:
#    population
# 0          12
# 1          34
# 2          56
# 3          78

# %%
pd.DataFrame(
    {"population" : [12,34,56,78],
     "area" : [1,2,4,6],
     "topic" : [987,234,765,987]}
)
# Out:
#    population  area  topic
# 0          12     1    987
# 1          34     2    234
# 2          56     4    765
# 3          78     6    987

# %%
population_dic = {
    "shiben" : 1234,
    "Tanta" : 9876,
    "Cairo" : 12345
}
population = pd.Series(population_dic)
population
# Out:
# shiben     1234
# Tanta      9876
# Cairo     12345
# dtype: int64

# %%
Area_dic = {
    "shiben" : 1123,
    "Tanta" : 788,
    "Cairo" : 9055
}
Area = pd.Series(Area_dic)
Area
# Out:
# shiben    1123
# Tanta      788
# Cairo     9055
# dtype: int64

# %%
school_dic = {
    "shiben" : 23,
    "Tanta" : 78,
    "Cairo" : 55
}
school = pd.Series(school_dic)
school
# Out:
# shiben    23
# Tanta     78
# Cairo     55
# dtype: int64

# %%
pd.DataFrame({
    "population" : population ,
    "Area" : Area ,
    "school" : school
})
# Out:
#         population  Area  school
# shiben        1234  1123      23
# Tanta         9876   788      78
# Cairo        12345  9055      55

# %%
import pandas as pd

# %%
path = r'C:\Users\Dr Maha Abdallah\Downloads\customers-10000.csv'
df = pd.read_csv(path)
df
# Out:
#       Index      Customer Id First Name   Last Name                   Company  \
# 0         1  EB54EF1154C3A78    Heather    Callahan              Mosley-David
# 1         2  10dAcafEBbA5FcA   Kristina     Ferrell  Horn, Shepard and Watson
# 2         3  67DAB15Ebe4BE4a     Briana    Andersen               Irwin-Oneal
# 3         4  6d350C5E5eDB4EE      Patty       Ponce          Richardson Group
# 4         5  5820deAdCF23EFe   Kathleen   Mccormick              Carson-Burch
# ...     ...              ...        ...         ...                       ...
# 9995   9996  DD0caa06ebf217c     Meghan       Cline            Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah        Pena               Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy         Key                  Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey                 Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery              Burns-Holden
#
# ...

# %%
df.head(5)
# Out:
#    Index      Customer Id First Name  Last Name                   Company  \
# 0      1  EB54EF1154C3A78    Heather   Callahan              Mosley-David
# 1      2  10dAcafEBbA5FcA   Kristina    Ferrell  Horn, Shepard and Watson
# 2      3  67DAB15Ebe4BE4a     Briana   Andersen               Irwin-Oneal
# 3      4  6d350C5E5eDB4EE      Patty      Ponce          Richardson Group
# 4      5  5820deAdCF23EFe   Kathleen  Mccormick              Carson-Burch
#
#                City                   Country                Phone 1  \
# 0  Lake Jeffborough                    Norway           043-797-5229
# 1        Aaronville                   Andorra           932-062-1802
# 2       East Jordan                     Nepal             8352752061
# 3  East Kristintown  Northern Mariana Islands           302.398.3833
# 4       Andresmouth                     Macao  001-184-153-9683x1497
#
#               Phone 2                             Email Subscription Date  \
# ...

# %%
df.tail(5)
# Out:
#       Index      Customer Id First Name   Last Name         Company  \
# 9995   9996  DD0caa06ebf217c     Meghan       Cline  Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah        Pena     Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy         Key        Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey       Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery    Burns-Holden
#
#                 City                       Country                Phone 1  \
# 9995      Petersport                 Cote d'Ivoire   001-270-136-4738x419
# 9996      Briggsport                       Namibia   +1-531-494-7645x4844
# 9997  West Joyceport  United States Virgin Islands     520.109.2482x26052
# 9998  Camachochester                         Niger       001-465-242-9979
# 9999      Sparkstown                       Tunisia  +1-889-682-9490x65400
#
#                     Phone 2                                 Email  \
# ...

# %%
df.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='str')

# %%
df["Last Name"]
# Out:
# 0         Callahan
# 1          Ferrell
# 2         Andersen
# 3            Ponce
# 4        Mccormick
#            ...
# 9995         Cline
# 9996          Pena
# 9997           Key
# 9998      Humphrey
# 9999    Montgomery
# Name: Last Name, Length: 10000, dtype: str

# %%
df["Last Name"][0 : 5]
# Out:
# 0     Callahan
# 1      Ferrell
# 2     Andersen
# 3        Ponce
# 4    Mccormick
# Name: Last Name, dtype: str

# %%
df.iloc[1:4]
# Out:
#    Index      Customer Id First Name Last Name                   Company  \
# 1      2  10dAcafEBbA5FcA   Kristina   Ferrell  Horn, Shepard and Watson
# 2      3  67DAB15Ebe4BE4a     Briana  Andersen               Irwin-Oneal
# 3      4  6d350C5E5eDB4EE      Patty     Ponce          Richardson Group
#
#                City                   Country       Phone 1  \
# 1        Aaronville                   Andorra  932-062-1802
# 2       East Jordan                     Nepal    8352752061
# 3  East Kristintown  Northern Mariana Islands  302.398.3833
#
#               Phone 2                          Email Subscription Date  \
# 1  (209)172-7124x3651        xreese@hall-donovan.com        2020-04-27
# 2       (567)135-1918  haleybraun@blevins-sexton.com        2022-03-22
# 3    196-189-7767x770           hohailey@anthony.com        2020-07-02
#
#                          Website
# 1       https://tyler-pugh.info/
# 2     https://www.mack-bell.net/
# 3  https://delacruz-freeman.org/

# %%
df.iloc[2,3]
# Out:
# 'Andersen'

# %%
for index , row in df.iterrows():
    print(index, row["Last Name"])
# Out:
# 0 Callahan
# 1 Ferrell
# 2 Andersen
# 3 Ponce
# 4 Mccormick
# 5 Lee
# 6 Hoffman
# 7 Wiggins
# 8 Payne
# 9 Franco
# 10 Hawkins
# 11 Shaffer
# 12 Moran
# 13 Hammond
# 14 Blackwell
# 15 Newton
# 16 Archer
# 17 Griffin
# 18 Valencia
# 19 Ramsey
# 20 Meadows
# 21 Brock
# 22 Pope
# 23 Stanton
# 24 Flynn
# 25 Williamson
# 26 Calderon
# 27 Walton
# 28 Mack
# 29 Jacobson
# 30 Harper
# 31 Mayer
# 32 Owens
# 33 Davies
# 34 Cruz
# 35 Hubbard
# 36 Bennett
# 37 Hansen
# 38 Foster
# 39 Medina
# 40 Santana
# 41 Moreno
# 42 Bush
# 43 Davenport
# 44 Terry
# 45 Esparza
# 46 Richard
# 47 Moore
# 48 Gillespie
# 49 Lin
# 50 Thomas
# 51 Fischer
# 52 West
# 53 Morton
# 54 Guerra
# 55 Shelton
# 56 Meza
# 57 Tapia
# 58 Powell
# 59 Irwin
# 60 Hodge
# 61 Drake
# 62 Tran
# 63 Webster
# 64 Mcclure
# 65 Wu
# 66 Bridges
# 67 Washington
# 68 Ayala
# 69 Hooper
# 70 Robbins
# 71 Cobb
# 72 Salas
# 73 Long
# 74 Kemp
# 75 Horn
# 76 Spears
# 77 Ortiz
# 78 Ortega
# 79 Cantu
# 80 Pittman
# 81 Cowan
# 82 Chen
# 83 Stanley
# ...

# %%
df.loc[df ["Country"] == "Andorra"]
# Out:
#       Index      Customer Id  First Name   Last Name  \
# 1         2  10dAcafEBbA5FcA    Kristina     Ferrell
# 696     697  Da63bffb10feFc2     Zachary        Tran
# 874     875  Ed3DDEE0De1b769       Becky      Obrien
# 1149   1150  80299d79EBDdfEa      Sierra        Lara
# 1202   1203  29f0D7dBdef8b72        Sean      Barron
# 1624   1625  a35FBCA4cf322cB      Laurie     Frazier
# 1652   1653  33109D4a0173C75  Kristopher     Mcmahon
# 1748   1749  56dE084ff34F362   Alejandra       Braun
# 1821   1822  aB5C6b1Fd82bF1f      Darren       Huynh
# 2197   2198  81d3bA3fC7CDA8C       James        Holt
# 2367   2368  CaF3696521b1Ec9      Lonnie       Weiss
# 2459   2460  75eff8a1c363EAe      Xavier      Gordon
# 2658   2659  900810eC061e685     Theresa     Wilkins
# 2885   2886  Ae692a12C8611cf      Brenda  Harrington
# 2991   2992  61c0EcFBbFD8Aad      Isaiah      Mathis
# 3184   3185  592dABd35E820b8      Pamela       Bruce
# 3531   3532  18FBb3A38dfCa58    Stefanie     Shannon
# ...

# %%
df.describe()
# Out:
#              Index
# count  10000.00000
# mean    5000.50000
# std     2886.89568
# min        1.00000
# 25%     2500.75000
# 50%     5000.50000
# 75%     7500.25000
# max    10000.00000

# %%
df.sort_values("Last Name", ascending = False)
# Out:
#       Index      Customer Id First Name Last Name                     Company  \
# 5771   5772  9eBD2acaCEb7b96       Tami    Zuniga                Small-Lucero
# 5755   5756  1FfeEeE3cCE7ccC    Rebecca    Zuniga                  Harris LLC
# 5320   5321  a4E042a4C2B9B3c        Ana    Zuniga     Bray, Bradford and Hart
# 2583   2584  c3928aAEf93beA7      Perry    Zuniga                Lawrence-Gay
# 1181   1182  6FfDBdaB1Ff440C    Garrett    Zuniga                 Mccarty Ltd
# ...     ...              ...        ...       ...                         ...
# 4828   4829  2DD738e7980FBcE       Alec    Abbott    Ali, Dalton and Mcknight
# 1296   1297  ABCFefFaDAc5F2C     Judith    Abbott                Potter-Haney
# 4544   4545  8a9a10BD9D46b9A    Felicia    Abbott                 Wood-Hinton
# 198     199  8A96EECfBD1E182      Robyn    Abbott  Dodson, Weaver and Barajas
# 6556   6557  BedfbB8AEADF1D5      Jimmy    Abbott                   Black Ltd
#
# ...

# %%
df.sort_values(["First Name" ,"Last Name"], ascending = True)
# Out:
#       Index      Customer Id First Name Last Name                     Company  \
# 9922   9923  196DcfDd1ABDeCa      Aaron      Berg    Wells, Dodson and Rhodes
# 995     996  a0e3B57D14C2F30      Aaron     Boyer              Burnett-Hinton
# 1647   1648  60BCf0CbBe6b27D      Aaron    Butler    Robertson, Wise and Love
# 9888   9889  602fC0BCBCDfC7F      Aaron  Campbell                   Cline Inc
# 9142   9143  C55290972eAFA23      Aaron     Cooke                   Ochoa Ltd
# ...     ...              ...        ...       ...                         ...
# 1863   1864  49FB80BFa60a782        Zoe      Pope                Campos-Clark
# 1031   1032  e9bC7F967aDEdbc        Zoe    Pruitt              Simon and Sons
# 431     432  BceA40c37Afe437        Zoe     Rojas  Browning, Hayes and Barber
# 907     908  ba09d8cDfF0eCf9        Zoe     Walls     Guerra, Reese and Banks
# 2306   2307  55ccE335EaAD335        Zoe     Walsh               Hughes-Steele
#
# ...

# %%
df.sort_values(["First Name" ,"Last Name"], ascending = [1,0])
# Out:
#       Index      Customer Id First Name  Last Name  \
# 8184   8185  Dfb02CB8A5cc89f      Aaron     Tucker
# 7300   7301  9B1d815c9eac9BB      Aaron    Spencer
# 9693   9694  DfEcb07E5Eef1eC      Aaron    Simpson
# 6545   6546  e9afebccEFCdDc3      Aaron       Pena
# 6914   6915  0dAEF35b5cCAa82      Aaron      Ortiz
# ...     ...              ...        ...        ...
# 6255   6256  A9aBbA57AF55c4c        Zoe    Pittman
# 9776   9777  531dE686fFE5b7b        Zoe  Nicholson
# 4722   4723  3aEBCDc0BF274AC        Zoe        Liu
# 5805   5806  5546c08f8E23d8c        Zoe      Hanna
# 7873   7874  5fcb4b2EAb8A38c        Zoe    Cochran
#
#                           Company              City     Country  \
# 8184   Trujillo, Kemp and Perkins        Port Sheri    Honduras
# 7300                  Cochran Inc        Shanemouth       Sudan
# 9693                   Cooley Inc     East Jeremiah  Mauritania
# 6545  Pollard, Michael and Powell   Port Gavinville      Angola
# ...

# %%
df. to_excel("customers.xlsx", index = False)

# %%
df.loc[(df['City'] == 'Petersport') & (df['Country'] == 'Norway')]
# Out:
# Empty DataFrame
# Columns: [Index, Customer Id, First Name, Last Name, Company, City, Country, Phone 1, Phone 2, Email, Subscription Date, Website]
# Index: []

# %%
df.loc[(df['City'] == 'Petersport') | (df['Country'] == 'Norway')]
# Out:
#       Index      Customer Id First Name  Last Name  \
# 0         1  EB54EF1154C3A78    Heather   Callahan
# 233     234  bA3c7355abEB0Aa   Danielle      Huang
# 293     294  78ac17Cc0E0b444      Danny       Hall
# 313     314  E44e636cfE26CfB      Maria     Conrad
# 383     384  8efE4D4084590A0     Kristi     Cortez
# 420     421  68fbb98f6EbD971       Jack    Robbins
# 480     481  d3fF4F1DceACA2D  Christian   Thornton
# 662     663  45fAcb9b399d894     Andres       Nash
# 1577   1578  23a1CeD8A626af7      Traci     Cooper
# 1862   1863  7d60D2dDF121acd      Cathy     Jarvis
# 1961   1962  3c4A0F6eC172711     Denise     Medina
# 2127   2128  0FE8eA68A3E2D0f    Patrick        Ray
# 2208   2209  F5f264c481eaE1d     Morgan     Robles
# 2260   2261  fA5FF5fbE098ea7      Randy      Rivas
# 2406   2407  eF265Ffe5F32251      Darin       Frye
# 2635   2636  A6acfb993EF51cd      Donna      Tyler
# 3220   3221  CC9B6713dc46eA7      Jerry     Howard
# ...

# %%
df.iloc[1]
# Out:
# Index                                       2
# Customer Id                   10dAcafEBbA5FcA
# First Name                           Kristina
# Last Name                             Ferrell
# Company              Horn, Shepard and Watson
# City                               Aaronville
# Country                               Andorra
# Phone 1                          932-062-1802
# Phone 2                    (209)172-7124x3651
# Email                 xreese@hall-donovan.com
# Subscription Date                  2020-04-27
# Website              https://tyler-pugh.info/
# Name: 1, dtype: object

# %%
df[["First Name", "Company" , "City"]]
# Out:
#      First Name                   Company              City
# 0       Heather              Mosley-David  Lake Jeffborough
# 1      Kristina  Horn, Shepard and Watson        Aaronville
# 2        Briana               Irwin-Oneal       East Jordan
# 3         Patty          Richardson Group  East Kristintown
# 4      Kathleen              Carson-Burch       Andresmouth
# ...         ...                       ...               ...
# 9995     Meghan            Richardson LLC        Petersport
# 9996   Jeremiah               Hodge-Nixon        Briggsport
# 9997      Peggy                  Vang LLC    West Joyceport
# 9998       Evan                 Gould Ltd    Camachochester
# 9999    Melissa              Burns-Holden        Sparkstown
#
# [10000 rows x 3 columns]
